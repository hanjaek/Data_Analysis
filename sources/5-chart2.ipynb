# %% [markdown]
# ### ***워드클라우드*** ###

# %%
#!pip install wikipedia

# %%
#!pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

import wikipedia
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %%
wiki = wikipedia.page('Artificial intelligence')
text = wiki.content
text
# Out:
# 'Artificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, particularly computer systems. It is a field of research in computer science that develops and studies methods and software that enable machines to perceive their environment and uses learning and intelligence to take actions that maximize their chances of achieving defined goals. Such machines may be called AIs.\nAI technology is widely used throughout industry, government, and science. Some high-profile applications include advanced web search engines (e.g., Google Search); recommendation systems (used by YouTube, Amazon, and Netflix); interacting via human speech (e.g., Google Assistant, Siri, and Alexa); autonomous vehicles (e.g., Waymo); generative and creative tools (e.g., ChatGPT and AI art); and superhuman play and analysis in strategy games (e.g., chess and Go). However, many AI applications are not perceived as AI: "A lot of cutting edge AI has filtered into general applications, of
# ...

# %%
wo = WordCloud(width = 2000, height = 1500).generate(text)
plt.imshow(wo) 
plt.show()

# %%
s_words = STOPWORDS.union( {'one', 'using', 'first', 'two', 'make', 'use','The'} )
wordcloud = WordCloud(width = 2000, height = 1500, stopwords = s_words).generate(text)
plt.imshow(wordcloud) 
plt.show()

# %% [markdown]
# !pip install konlpy

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\root\\M1'

# %%
from collections import Counter
from konlpy.tag import Okt
import numpy as np
from wordcloud import *

# %%
#with open('data\대한민국헌법.txt', 'r', encoding='utf-8')  as f: 
with open('.\data\애국가.txt', 'r', encoding='utf-8') as f:    
    text = f.read()    
okt = Okt()
nouns = okt.nouns(text)
words = [n for n in nouns if len(n)>1]
c = Counter(words)
print("nouns -> ",nouns)
print("words -> ",words)
print("c -> "    ,c)
# Out:
# nouns ->  ['해물', '백두산', '마르고', '하느님', '보우', '하사', '우리나라', '만세', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전', '남산', '위', '저', '소나무', '철갑', '듯', '바람', '서리', '불변', '함', '우리', '기상', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전', '가을', '하늘', '활', '데', '구름', '달', '우리', '가슴', '일편단심', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전', '이', '기상', '이', '맘', '충성', '나라', '사랑', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전']
# words ->  ['해물', '백두산', '마르고', '하느님', '보우', '하사', '우리나라', '만세', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전', '남산', '소나무', '철갑', '바람', '서리', '불변', '우리', '기상', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전', '가을', '하늘', '구름', '우리', '가슴', '일편단심', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전', '기상', '충성', '나라', '사랑', '무궁화', '삼천리', '화려', '강산', '대한', '사람', '대한', '길이', '보전']
# ...

# %%
wc = WordCloud(font_path='malgun.ttf', width=400, height=400, 
               scale=2.0, max_font_size=250)
##wc = WordCloud(font_path='/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf',
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)
#wc.to_file('data\\헌법_워드클라우드.png')
wc.to_file('data\\애국가.png')

# %% [markdown]
# ### ***konlpy***
# >- https://konlpy.org/ko/v0.5.1/api/konlpy.tag/
# >-
# ### ***Hannanum***
# >- https://www.sketchengine.eu/wp-content/uploads/Original-HanNanum-manual.pdf

# %%
from konlpy.tag import Kkma
from konlpy.utils import pprint

kkma = Kkma()
pprint(kkma.sentences(u'네, 안녕하세요. 반갑습니다.'))
pprint(kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.'))
pprint(kkma.pos(u'오류보고는 실행환경, 에러메세지와함께 설명을 최대한상세히!^^'))
# Out:
# ['네, 안녕하세요.', '반갑습니다.']
# ['질문', '건의', '건의사항', '사항', '깃헙', '이슈', '트래커']
# [('오류', 'NNG'),
#  ('보고', 'NNG'),
#  ('는', 'JX'),
#  ('실행', 'NNG'),
#  ('환경', 'NNG'),
#  (',', 'SP'),
#  ('에러', 'NNG'),
#  ('메세지', 'NNG'),
#  ('와', 'JKM'),
#  ('함께', 'MAG'),
#  ('설명', 'NNG'),
#  ('을', 'JKO'),
#  ('최대한', 'NNG'),
#  ('상세히', 'MAG'),
#  ('!', 'SF'),
#  ('^^', 'EMO')]

# %%
from collections import Counter

from konlpy.corpus import kolaw
from konlpy.tag import Hannanum
from konlpy.utils import concordance, pprint
from matplotlib import pyplot
import codecs

def draw_zipf(count_list, filename, color='blue', marker='o'):
    sorted_list = sorted(count_list, reverse=True)
    pyplot.plot(sorted_list, color=color, marker=marker)
    pyplot.xscale('log')
    pyplot.yscale('log')
    pyplot.savefig(filename)

INPUT_FILE_NAME = 'data\\say.txt'

read_file = codecs.open(INPUT_FILE_NAME, 'r', 'utf-8-sig')
doc = read_file.read()
pos = Hannanum().nouns(doc)
cnt = Counter(pos)

print('nchars  :', len(doc))
print('nouns :', len(set(pos)))
print('\nTop 20 frequent morphemes:'); pprint(cnt.most_common(20))
print('\nLocations of "대한민국" in the document:')
concordance(u'대한민국', doc, show=True)

draw_zipf(cnt.values(), 'data\\zipf.png')
# Out:
# nchars  : 3131
# nouns : 310
#
# Top 20 frequent morphemes:
# [('것', 31),
#  ('우리', 26),
#  ('나', 11),
#  ('수', 11),
#  ('자리', 7),
#  ('이', 6),
#  ('일', 6),
#  ('말', 5),
#  ('사람', 5),
#  ('바', 5),
#  ('눈물', 4),
#  ('나라', 4),
#  ('중', 4),
#  ('세계', 4),
#  ('친선', 4),
#  ('대우', 4),
#  ('오늘', 3),
#  ('책', 3),
#  ('40년', 3),
#  ('전', 3)]
#
# Locations of "대한민국" in the document:
# 127	민족전체의 행복을 위하여 대한민국의 국민 된
# 732	위에 세우기로 결심합니다. 대한민국 30년 7월24일
# 735	대한민국 30년 7월24일 대한민국 대통령 이승만

# %%
INPUT_FILE_NAME = 'data\\say2.txt'

read_file = codecs.open(INPUT_FILE_NAME, 'r', 'utf-8-sig')
doc = read_file.read()
pos = Hannanum().nouns(doc)
cnt = Counter(pos)

print('nchars  :', len(doc))
print('nouns :', len(set(pos)))
print('\nTop 20 frequent morphemes:'); pprint(cnt.most_common(20))
print('\nLocations of "대한민국" in the document:')
concordance(u'대한민국', doc, show=True)

draw_zipf(cnt.values(), 'data\\zipf2.png')
# Out:
# nchars  : 3164
# nouns : 278
#
# Top 20 frequent morphemes:
# [('대통령', 27),
#  ('국민', 21),
#  ('저', 14),
#  ('대한민국', 10),
#  ('여러분', 8),
#  ('나라', 7),
#  ('우리', 7),
#  ('것', 7),
#  ('역사', 6),
#  ('일', 6),
#  ('존경', 5),
#  ('오늘', 5),
#  ('세상', 5),
#  ('선거', 5),
#  ('대통령의', 5),
#  ('이번', 4),
#  ('정치', 4),
#  ('국민들', 4),
#  ('시작', 4),
#  ('대화', 4)]
#
# Locations of "대한민국" in the document:
# 14	감사드립니다. 저는 오늘 대한민국 제19대 대통령으로서
# 18	제19대 대통령으로서 새로운 대한민국을 향해 첫걸음을
# 57	우리가 만들어가려는 새로운 대한민국은 숱한 좌절과
# 79	싶어했던 나라입니다. 그런 대한민국을 만들기 위해
# 89	두렵지만 겸허한 마음으로 대한민국 제19대 대통령으로서의
# 114	없습니다. 우리는 새로운 대한민국을 함께 이끌어가야
# 148	탄핵과 구속앞에서도 국민들이 대한민국의 앞길을 열어주셨습니다.
# 165	새로운 세상을 열었습니다. 대한민국의 위대함은 국민의
# 490	종식돼야 합니다. 저는 대한민국 대통령의 새로운
# 637	2017년 5월10일 오늘 대한민국이 다시 시작합니다.

# %%
#!pip install pytagcloud 
#!pip install pygame
#!pip install simplejson

# %%
from collections import Counter

from konlpy.corpus import kolaw
from konlpy.tag import Hannanum
from konlpy.utils import concordance, pprint
from matplotlib import pyplot
import codecs
import random
import webbrowser
import pytagcloud 
# requires Korean font support

def get_tags(text, ntags=50, multiplier=10):
    h = Hannanum()
    nouns = h.nouns(text)
    count = Counter(nouns)
    return [{ 'color': color(), 'tag': n, 'size': c*multiplier }\
                for n, c in count.most_common(ntags)]

def draw_cloud(tags, filename, fontname='Nanum Gothic', size=(1024,768)):
    pytagcloud.create_tag_image(tags, filename, size=size)
    webbrowser.open(filename)

INPUT_FILE_NAME = 'data\\say2.txt'

r = lambda: random.randint(0,255)
color = lambda: (r(), r(), r())

read_file = codecs.open(INPUT_FILE_NAME, 'r', 'utf-8-sig')
doc = read_file.read()
tags = get_tags(doc)

print(tags)

draw_cloud(tags, 'data\\say.png')
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ...

# %%
INPUT_FILE_NAME = 'data\say2.txt'

r = lambda: random.randint(0,255)
color = lambda: (r(), r(), r())

read_file = codecs.open(INPUT_FILE_NAME, 'r', 'utf-8-sig')
doc = read_file.read()
tags = get_tags(doc)

print(tags)

draw_cloud(tags, 'data\\say2.png')
# Out:
# [{'color': (3, 196, 0), 'tag': '대통령', 'size': 270}, {'color': (109, 123, 190), 'tag': '국민', 'size': 210}, {'color': (248, 106, 157), 'tag': '저', 'size': 140}, {'color': (227, 178, 77), 'tag': '대한민국', 'size': 100}, {'color': (184, 125, 26), 'tag': '여러분', 'size': 80}, {'color': (246, 239, 255), 'tag': '나라', 'size': 70}, {'color': (50, 44, 150), 'tag': '우리', 'size': 70}, {'color': (116, 66, 168), 'tag': '것', 'size': 70}, {'color': (118, 109, 216), 'tag': '역사', 'size': 60}, {'color': (174, 154, 173), 'tag': '일', 'size': 60}, {'color': (150, 255, 181), 'tag': '존경', 'size': 50}, {'color': (120, 97, 160), 'tag': '오늘', 'size': 50}, {'color': (249, 76, 194), 'tag': '세상', 'size': 50}, {'color': (217, 134, 231), 'tag': '선거', 'size': 50}, {'color': (74, 145, 181), 'tag': '대통령의', 'size': 50}, {'color': (240, 201, 191), 'tag': '이번', 'size': 40}, {'color': (206, 17, 244), 'tag': '정치', 'size': 40}, {'color': (149, 161, 4), 'tag': '국민들', 'size': 40}, {'color': (179, 38, 242), 'tag': '시작', 'size': 40}
# ...
