# %% [markdown]
# ### **차트 matPlotLib**

# %%
#차트에서 한글을 지원하는 글꼴 세팅

import platform
from matplotlib import font_manager, rc 
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Windows':   ## 윈도우즈 운영체제
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name() 
    rc('font', family=font_name)
    
elif platform.system() == 'Darwin': ## 맥운영체제
    rc('font', family='AppleGothic')
    
elif platform.system() == 'Linux':   ## 유닉스, 리눅스
    rc('font', family='NanumBarunGothic')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from pandas import *
from numpy import *

# %%
plt.figure(figsize=(3,2))
plt.title("Plot")
plt.plot([1,4,9,16])  
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.plot([10,20,30,40],[100,4,9,16])
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.plot([10,20,30,40],[1,4,9,16],'bo-.')
plt.show()

# %%
plt.figure(figsize=(3,2))
plt.plot([10,20,30,40],[1,4,9,16], c="b",lw=5, ls="-.", 
         marker="o", ms=10, mec="g", mew=5, mfc="#ff00ff")
plt.show()

# %%
np.random.rand(4)
# Out:
# array([0.45330447, 0.34461626, 0.79664024, 0.21137201])

# %%
np.random.randn(4)
# Out:
# array([-0.41746578, -0.72703159,  0.37382908, -0.11158925])

# %%
np.random.randint(1,7,(3,2))
# Out:
# array([[4, 4],
#        [2, 1],
#        [4, 5]])

# %%
plt.plot(np.random.randn(30), 'ko--')

# %%
x = range(100)
y = np.random.rand(100)

plt.figure(figsize=(3,2))
plt.scatter(x,y)
plt.xlabel('x 축')
plt.ylabel('y 축')
# Out:
# Text(0, 0.5, 'y 축')

# %%
n = 10
y = np.random.randn(n)

plt.figure(figsize=(3,2))
plt.plot(range(n), y)
plt.xlabel('시간')
plt.ylabel('랜덤 값')
# Out:
# Text(0, 0.5, '랜덤 값')

# %%
X=np.linspace(-np.pi,np.pi,10) 
print(X)
C=np.cos(X)
print(C)
# Out:
# [-3.14159265 -2.44346095 -1.74532925 -1.04719755 -0.34906585  0.34906585
#   1.04719755  1.74532925  2.44346095  3.14159265]
# [-1.         -0.76604444 -0.17364818  0.5         0.93969262  0.93969262
#   0.5        -0.17364818 -0.76604444 -1.        ]

# %%
X=np.linspace(-np.pi,np.pi,256) 
C=np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X,C, label="테스트")
plt.xlabel("x축 이름")
plt.ylabel("y축 이름")
plt.xticks([-np.pi,    -np.pi/2,    0,   np.pi/2,    np.pi])
plt.yticks([-1,0,+1])
plt.xlim([-4.0, +4.0])
plt.ylim([-2.0, +2.0])
plt.legend(loc=3)

# %%
## 몬테카를로 분석
n = 100000
x = np.random.rand(n)
y = np.random.rand(n) 
plt.figure(figsize=(3,3)) 
plt.scatter(x,y, s=1) 
xx=np.linspace(0,1,100) 
plt.plot(xx, (1-xx*xx)**0.5, c='r')
pi = ((x**2 + y**2) < 1).mean()*4 
pi
# Out:
# 3.14148

# %%
n = 5
x = np.random.rand(n).round(2)
y = np.random.rand(n).round(2)
x,y
# Out:
# (array([0.87, 0.22, 0.96, 0.24, 0.77]), array([0.02, 0.45, 0.94, 0.93, 0.41]))

# %%
plt.figure(figsize=(3,3)) 
plt.scatter(x,y, s=50)

# %%
xx=np.linspace(0,1,100) 
plt.figure(figsize=(3,3)) 
plt.plot(xx, (1-xx*xx)**0.5, c='r')

# %%
z = np.random.rand(500000)
(z < 0.5).mean()
# Out:
# 0.500268

# %%
pi = ((x**2 + y**2) < 1).mean()*4

# %%
x = np.random.randint(1,7, 5) ;x
# Out:
# array([2, 5, 6, 4, 4])

# %%
x = np.random.randint(1,7,100000) 
plt.hist(x, bins = 6, width=0.6) 
plt.show()

# %%
z = 0
n = 32 
for i in range(n):
    x = np.random.randint(1,7,10000) 
    z = z + x
plt.hist(z, bins = n*5+1, width=0.6) 
plt.show()

# %%
x = np.random.randn(100000) 
plt.hist(x, bins = 100, width=0.03) 
plt.show()

# %%
axes = plt.subplots(2, 3) 
axes
# Out:
# (<Figure size 640x480 with 6 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %%
fig = plt.figure() 
ax1 = fig.add_subplot(2, 2, 1) 
ax2 = fig.add_subplot(2, 2, 2) 
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)
ax1.hist(np.random.randn(200), bins=20, color='k', rwidth=0.5)
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))
ax3.plot(np.arange(10),np.random.randn(10))

# %%
fig2 = plt.figure() 

ax1=plt.subplot(221) 
ax2=plt.subplot(222)
ax3=plt.subplot(223)
ax4=plt.subplot(224)

ax1.hist(np.random.randn(200), bins=20, color='k', rwidth=0.5)
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))
ax3.plot(np.arange(10),np.random.randn(10))  
ax4.hist(np.random.randint(1,7,1000), bins = 6, width=1)
# Out:
# (array([149., 171., 174., 166., 167., 173.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)

# %%
ax1.hist(np.random.randn(200), bins=20, color='k', rwidth=0.5)
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30))
ax3.plot(np.arange(10),np.random.randn(10))
fig2

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %%
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=None)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):    
    for j in range(2):        
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0.5, hspace=0.5, left=0.5, top=0.5)

# %%
times = [8, 14, 2]
timelabels = ["Sleep", "Study", "Play"]
plt.pie(times, labels = timelabels, autopct = "%.1f") 
plt.savefig("b.png", dpi=600)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'r', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'k--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'b.', label='three')

ax.legend(loc='best')

# %%
fig, axes = plt.subplots(2, 1)
data = Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='k', alpha=0.9)
data.plot(kind='barh', ax=axes[1], color='k', alpha=0.7)
# Out:
# <Axes: >

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.2, 0.75), 0.5, 0.2, color='k', alpha=0.3) 
##(0.2,0.75) 사각형의 시작점 0.5 가로길이 0.2 세로길이를 뜻한다.
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3) 
## (0,7,0,2) 원의 중심 을 뜻한다 / 0.15 원의 반지름을 뜻한다.
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)
#꼭지점의 좌표
                   
ax.add_patch(rect) ## ax subplot에 도형을 추가한다.
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
df = DataFrame(np.random.rand(6, 4), index=['one', 'two', 'three', 'four', 'five', 'six'], columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.plot(kind='barh', stacked=True)
# Out:
# <Axes: >

# %%
#표준정규분포로 임의의 값을 추출  (평균, 표준편차, 갯수)
a = np.random.normal(0, 1, 10)
b = np.random.normal(10, 2,10)
## a와 b는 배열

# %%
c = np.concatenate( [a, b] ) ## a, b 배열을 합치기
c
# Out:
# array([ 1.20879401,  0.37394114, -0.81393024, -0.36126798,  0.51840111,
#        -1.1413768 ,  0.23374987, -0.84891888, -0.32497777,  1.26265223,
#        12.02529532, 11.14989062,  5.97733047, 10.85153565,  9.98766739,
#        11.09021725,  9.45548249,  7.41008097,  8.77326945, 12.36517702])

# %%
d = Series( np.concatenate( [a, b] ) )
d
# Out:
# 0      1.208794
# 1      0.373941
# 2     -0.813930
# 3     -0.361268
# 4      0.518401
# 5     -1.141377
# 6      0.233750
# 7     -0.848919
# 8     -0.324978
# 9      1.262652
# 10    12.025295
# 11    11.149891
# 12     5.977330
# 13    10.851536
# 14     9.987667
# 15    11.090217
# 16     9.455482
# 17     7.410081
# 18     8.773269
# 19    12.365177
# dtype: float64

# %%
# 확률밀도
comp1 = np.random.normal(0, 1, size=200)  
comp2 = np.random.normal(10, 2, size=200) 
values = Series(np.concatenate([comp1, comp2])) 
values.hist(bins=100, alpha=0.3, color='k', density=True)
values.plot(kind='kde', style='r--')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.savefig('.\data\\test.png')
