# %% [markdown]
# # 스타벅스 매장 데이터와 지도
#
#
# * json_normalize(): JSON 데이터 DataFrame으로 전환
# * folium 을 사용하여 지도에 위치 표시

# %% [markdown]
# # 스타벅스 매장찾기
# http://www.istarbucks.co.kr
#
# * STORE >> 매장 찾기
# * 지역검색 >> 서울 >> 전체

# %%
import requests
import json
import pandas as pd
from pandas import *

# %config InlineBackend.figure_format = 'retina'

# %%
data = {
    'ins_lat':'37.56682', # 지정한 위도와 경도에서 가까운 순으로 나열
    'ins_lng':'126.97865',
    'p_sido_cd':'01', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.starbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)

r.text[:1000] # 수신된 데이터의 앞부분만 확인
# Out:
# '{"list":[{"seq":0,"sido_cd":null,"sido_nm":null,"gugun_cd":null,"gugun_nm":null,"code_order":null,"view_yn":null,"store_num":null,"sido":null,"gugun":null,"address":null,"new_img_nm":null,"p_pro_seq":0,"p_view_yn":null,"p_sido_cd":"","p_gugun_cd":"","p_store_nm":null,"p_theme_cd":null,"p_wireless_yn":null,"p_smoking_yn":null,"p_book_yn":null,"p_music_yn":null,"p_terrace_yn":null,"p_table_yn":null,"p_takeout_yn":null,"p_parking_yn":null,"p_dollar_assent":null,"p_card_recharge":null,"p_subway_yn":null,"stb_store_file_renew":null,"stb_store_theme_renew":null,"stb_store_time_renew":null,"stb_store_lsm":null,"s_code":"1509","s_name":"역삼아레나빌딩","tel":"1522-3232","dlvry_call_cntr_phno":null,"fax":"02-568-3763","sido_code":"01","sido_name":"서울","gugun_code":"0101","gugun_name":"강남구","addr":"서울특별시 강남구 역삼동 721-13 아레나빌딩","park_info":null,"new_state":null,"theme_state":"Z9999@T05@T08@T16@T17@T20@T21@T30@T36@@T43@T52@T56@T57@T64@T65@T69@T71@P80@P90","new_bool":0,"search_text":"","ins_lat":"","ins_ln'

# %% [markdown]
# 데이터는 JSON으로 수신되며, 형태는 다음과 같다.
#
# ```json
# {
#   "list": [
#       {
#             // ... 중략 ...
#             "s_code": "1311",
#             "s_name": "방화DT",
#             "tel": "02-2664-3480",
#             "fax": "02-2664-3481",
#             "sido_code": "01",
#             "sido_name": "서울",
#             "gugun_code": "0103",
#             "gugun_name": "강서구",
#             "addr": "서울특별시 강서구 방화동 293-4",
#             "park_info": null,
#             "new_state": null,
#             "theme_state": "T17@T16@T09@T20@T01@T05@T08@T04",
#             // ... 중략 ...
#             "lat": "37.574339",
#             "lot": "126.816415",
#             "t22": 0
#         },
#         {
#             // ... 중략 ...
#             "s_code": "1267",
#             "s_name": "마곡나루역",
#             "tel": "02-3662-3504",
#             "fax": "02-3662-3505",
#             "sido_code": "01",
#             "sido_name": "서울",
#             "gugun_code": "0103",
#             "gugun_name": "강서구",
#             "addr": "서울특별시 강서구 마곡동 759-3 보타닉파크타워Ⅰ105,203,204호",
#             "park_info": null,
#             "new_state": null,
#             "theme_state": "T08@T05@T04@T17@T16@P80@T20",
#             // ... 중략 ...
#             "lat": "37.56813",
#             "lot": "126.82614",
#             "t22": 0
#         },
#     ]
#  }
# ```

# %% [markdown]
# # JSON to DataFrame
#
# json_normalize() 를 사용하여 JSON 데이터를 DataFrame로 전환

# %%
#r.text

# %%
jo = json.loads(r.text)
#print(jo)

# %%
df = json_normalize(jo, 'list')  ## 정규화
#print(df)

# %%
# 행(row)수, 서울 643개 매장
len(df)
# Out:
# 643

# %%
# 컬럼수 137개
df.columns
# Out:
# Index(['seq', 'sido_cd', 'sido_nm', 'gugun_cd', 'gugun_nm', 'code_order',
#        'view_yn', 'store_num', 'sido', 'gugun',
#        ...
#        't30', 't36', 't27', 't29', 't43', 't48', 'z9999', 't64', 't66', 'p02'],
#       dtype='object', length=137)

# %%
# 주요한 컬럼 몇 가지 선택
df = df[ ['s_name', 'lat', 'lot', 'sido_name', 'gugun_name', 'doro_address', 'tel'] ] 
df.head(4)
# Out:
#     s_name         lat          lot sido_name gugun_name  \
# 0  역삼아레나빌딩   37.501087   127.043069        서울        강남구
# 1   논현역사거리   37.510178   127.022223        서울        강남구
# 2  신사역성일빌딩  37.5139309  127.0206057        서울        강남구
# 3   국기원사거리   37.499517   127.031495        서울        강남구
#
#                doro_address        tel
# 0   서울특별시 강남구 언주로 425 (역삼동)  1522-3232
# 1  서울특별시 강남구 강남대로 538 (논현동)  1522-3232
# 2  서울특별시 강남구 강남대로 584 (논현동)  1522-3232
# 3  서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232

# %% [markdown]
# # 위도 경도 데이터 타입 변환

# %%
df.dtypes
# Out:
# s_name          object
# lat             object
# lot             object
# sido_name       object
# gugun_name      object
# doro_address    object
# tel             object
# dtype: object

# %% [markdown]
# ### lat, lot타입으로 전환 (str→float)

# %%
df['lat'] = df['lat'].astype(float)
df['lot'] = df['lot'].astype(float)

# %%
df.dtypes
# Out:
# s_name           object
# lat             float64
# lot             float64
# sido_name        object
# gugun_name       object
# doro_address     object
# tel              object
# dtype: object

# %% [markdown]
# ### 특정 지점

# %%
df[df['s_name'] == '논현역사거리'] # 시청점
# Out:
#    s_name        lat         lot sido_name gugun_name  \
# 1  논현역사거리  37.510178  127.022223        서울        강남구
#
#                doro_address        tel
# 1  서울특별시 강남구 강남대로 538 (논현동)  1522-3232

# %% [markdown]
# 스타벅스 시청점의 위도(lat)와 경도(lot)는 각각  37.56629, 126.979808

# %% [markdown]
# # folium
# https://github.com/python-visualization/folium
#
# 파이썬 지리정보 시각화 모듈  (문서: https://folium.readthedocs.io )

# %% [markdown]
# !pip install folium

# %%
import folium

# 서울 시청 
map_osm = folium.Map(location=(37.56629, 126.979808))
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf24b9202a0c54b0928065f8c925e864 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf24b9202a0c54b0928065f8c925e864&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf24b9202a0c54b0928065f8c925e864 = L.map(
#                 &quot;map_bf24b9202a0c54b0928065f8c925e864&quot;,
#                 {
#                     center: [37.56629, 126.979808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_516a4b47c447785be2e4fa390f78902b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_516a4b47c447785be2e4fa390f78902b.addTo(map_bf24b9202a0c54b0928065f8c925e864);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 지도를 상하좌우로 움직이거나 확대/축소 할 수 있다

# %%
# 확대 지정 (zoom_start)
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6df8bee096770cb44ee0c8a353a16caa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6df8bee096770cb44ee0c8a353a16caa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6df8bee096770cb44ee0c8a353a16caa = L.map(
#                 &quot;map_6df8bee096770cb44ee0c8a353a16caa&quot;,
#                 {
#                     center: [37.56629, 126.979808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f24e6f3bad2a995a5e52bb7253739b43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f24e6f3bad2a995a5e52bb7253739b43.addTo(map_6df8bee096770cb44ee0c8a353a16caa);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 tiles 지정
map_osm = folium.Map(location=(37.56629, 126.979808), zoom_start=17, tiles='CartoDB Positron')
# “OpenStreetMap”, “CartoDB Positron”, “CartoDB Voyager”
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9df2b07caf69ff27945be5019d8e00c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9df2b07caf69ff27945be5019d8e00c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9df2b07caf69ff27945be5019d8e00c4 = L.map(
#                 &quot;map_9df2b07caf69ff27945be5019d8e00c4&quot;,
#                 {
#                     center: [37.56629, 126.979808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc63ee8a79443be9faf5f6c58bed22db = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc63ee8a79443be9faf5f6c58bed22db.addTo(map_9df2b07caf69ff27945be5019d8e00c4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
시청_좌표=(37.56629, 126.979808)
 
map_osm = folium.Map(location=시청_좌표, zoom_start=17)
folium.Marker(시청_좌표, popup='시청').add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_23958e9f7a356f17c4a368079cb1852e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_23958e9f7a356f17c4a368079cb1852e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_23958e9f7a356f17c4a368079cb1852e = L.map(
#                 &quot;map_23958e9f7a356f17c4a368079cb1852e&quot;,
#                 {
#                     center: [37.56629, 126.979808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acb2d5f97e9e3e1e3a353e90f890263b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_acb2d5f97e9e3e1e3a353e90f890263b.addTo(map_23958e9f7a356f17c4a368079cb1852e);
#
#
#             var marker_6065c44230636961c92b0b05d6cec5bc = L.marker(
#                 [37.56629, 126.979808],
#                 {}
#             ).addTo(map_23958e9f7a356f17c4a368079cb1852e);
#
#
#         var popup_5030295d4adb5d12437052f42491edca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f3e1d74cd1c5c3befe31a0079343120 = $(`&lt;div id=&quot;html_1f3e1d74cd1c5c3befe31a0079343120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;시청&lt;/div&gt;`)[0];
#                 popup_5030295d4adb5d12437052f42491edca.setContent(html_1f3e1d74cd1c5c3befe31a0079343120);
#
#
#
#         marker_6065c44230636961c92b0b05d6cec5bc.bindPopup(popup_5030295d4adb5d12437052f42491edca)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[37.56629, 126.979808], tiles='OpenStreetMap', zoom_start=13)
folium.Marker([37.56629, 126.979808], popup='The Waterfront').add_to(map)
folium.CircleMarker([37.56629, 126.979808], radius=50,
                   popup='시청', color='red',
                   fill_color='#3186cc').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f22ba1ef1b41e8006db4406463122183 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f22ba1ef1b41e8006db4406463122183&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f22ba1ef1b41e8006db4406463122183 = L.map(
#                 &quot;map_f22ba1ef1b41e8006db4406463122183&quot;,
#                 {
#                     center: [37.56629, 126.979808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28f2a076f2608cd19c0fb28d7e886b8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_28f2a076f2608cd19c0fb28d7e886b8d.addTo(map_f22ba1ef1b41e8006db4406463122183);
#
#
#             var marker_70f6f2cf09763e82215a6e4b7833c4e8 = L.marker(
#                 [37.56629, 126.979808],
#                 {}
#             ).addTo(map_f22ba1ef1b41e8006db4406463122183);
#
#
#         var popup_e51e9ad22b20d72d97f4155b124be56d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d928ce04e46580e3af42e83e36d58af4 = $(`&lt;div id=&quot;html_d928ce04e46580e3af42e83e36d58af4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_e51e9ad22b20d72d97f4155b124be56d.setContent(html_d928ce04e46580e3af42e83e36d58af4);
#
#
#
#         marker_70f6f2cf09763e82215a6e4b7833c4e8.bindPopup(popup_e51e9ad22b20d72d97f4155b124be56d)
#         ;
#
#
#
#
#             var circle_marker_c575637d1fa7aabfd009d699d0d4548f = L.circleMarker(
#                 [37.56629, 126.979808],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_f22ba1ef1b41e8006db4406463122183);
#
#
#         var popup_5d10c5409d32bf9ccb7e712422e12c0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_232a21c4bfe132f50eb31ac4f771e353 = $(`&lt;div id=&quot;html_232a21c4bfe132f50eb31ac4f771e353&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;시청&lt;/div&gt;`)[0];
#                 popup_5d10c5409d32bf9ccb7e712422e12c0e.setContent(html_232a21c4bfe132f50eb31ac4f771e353);
#
#
#
#         circle_marker_c575637d1fa7aabfd009d699d0d4548f.bindPopup(popup_5d10c5409d32bf9ccb7e712422e12c0e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 서울 스타벅스 전 지점

# %%
map_osm = folium.Map(location=시청_좌표, zoom_start=11)

for ix, row in df.iterrows():
    location = (row['lat'], row['lot'])
    folium.Marker(location, popup=row['s_name']).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c03cb148595f5672ec39e354ceabe72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c03cb148595f5672ec39e354ceabe72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c03cb148595f5672ec39e354ceabe72 = L.map(
#                 &quot;map_3c03cb148595f5672ec39e354ceabe72&quot;,
#                 {
#                     center: [37.56629, 126.979808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b5b31bbb48564f859d0a5fc9c3732c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b5b31bbb48564f859d0a5fc9c3732c2.addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#             var marker_33ba422bcc1b06f7ea32f9928ad90cf8 = L.marker(
#                 [37.501087, 127.043069],
#                 {}
#             ).addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#         var popup_7f39aaa6c5f8c26d29ea169630ef59a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c836b6ef2d1989000478c77ddbccb264 = $(`&lt;div id=&quot;html_c836b6ef2d1989000478c77ddbccb264&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;역삼아레나빌딩&lt;/div&gt;`)[0];
#                 popup_7f39aaa6c5f8c26d29ea169630ef59a4.setContent(html_c836b6ef2d1989000478c77ddbccb264);
#
#
#
#         marker_33ba422bcc1b06f7ea32f9928ad90cf8.bindPopup(popup_7f39aaa6c5f8c26d29ea169630ef59a4)
#         ;
#
#
#
#
#             var marker_a59e0c401261db54407b9d76a9613820 = L.marker(
#                 [37.510178, 127.022223],
#                 {}
#             ).addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#         var popup_f78e633181182bdc9aad3369a9073af1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_876415a1c3f6f295d1b1639c63318494 = $(`&lt;div id=&quot;html_876415a1c3f6f295d1b1639c63318494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;논현역사거리&lt;/div&gt;`)[0];
#                 popup_f78e633181182bdc9aad3369a9073af1.setContent(html_876415a1c3f6f295d1b1639c63318494);
#
#
#
#         marker_a59e0c401261db54407b9d76a9613820.bindPopup(popup_f78e633181182bdc9aad3369a9073af1)
#         ;
#
#
#
#
#             var marker_bf5c4308cd111e44d54e6b9e1781b26a = L.marker(
#                 [37.5139309, 127.0206057],
#                 {}
#             ).addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#         var popup_7c797b45462acee64efe4337675aff53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29d4f3a3973fa99140c32c49d3847f3d = $(`&lt;div id=&quot;html_29d4f3a3973fa99140c32c49d3847f3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;신사역성일빌딩&lt;/div&gt;`)[0];
#                 popup_7c797b45462acee64efe4337675aff53.setContent(html_29d4f3a3973fa99140c32c49d3847f3d);
#
#
#
#         marker_bf5c4308cd111e44d54e6b9e1781b26a.bindPopup(popup_7c797b45462acee64efe4337675aff53)
#         ;
#
#
#
#
#             var marker_d1558cb212d4f4b60eaf5b19850c6a7d = L.marker(
#                 [37.499517, 127.031495],
#                 {}
#             ).addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#         var popup_ffd8356c316cd971310c4914f330300a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7936b8c6a73ca5dd818dd4c4c24195e3 = $(`&lt;div id=&quot;html_7936b8c6a73ca5dd818dd4c4c24195e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;국기원사거리&lt;/div&gt;`)[0];
#                 popup_ffd8356c316cd971310c4914f330300a.setContent(html_7936b8c6a73ca5dd818dd4c4c24195e3);
#
#
#
#         marker_d1558cb212d4f4b60eaf5b19850c6a7d.bindPopup(popup_ffd8356c316cd971310c4914f330300a)
#         ;
#
#
#
#
#             var marker_b584651206360e65fa1520f0ecda3e2d = L.marker(
#                 [37.494668, 127.062583],
#                 {}
#             ).addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#         var popup_991e187c5090c71e3ce707c97b1ccd03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07a14da11ff8d535a264279cf544e1f2 = $(`&lt;div id=&quot;html_07a14da11ff8d535a264279cf544e1f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대치재경빌딩&lt;/div&gt;`)[0];
#                 popup_991e187c5090c71e3ce707c97b1ccd03.setContent(html_07a14da11ff8d535a264279cf544e1f2);
#
#
#
#         marker_b584651206360e65fa1520f0ecda3e2d.bindPopup(popup_991e187c5090c71e3ce707c97b1ccd03)
#         ;
#
#
#
#
#             var marker_d794e4bed414c0ec6435a483e960131a = L.marker(
#                 [37.515, 127.063196],
#                 {}
#             ).addTo(map_3c03cb148595f5672ec39e354ceabe72);
#
#
#         var popup_a9

# %% [markdown]
# # 제주도 스타벅스 매장 지도

# %%
import requests
import json
import pandas as pd
한라산_좌표 = (33.361666, 126.529166)
data = {
    'ins_lat': '33.4996213', # 제주 시청의 좌표
    'ins_lng': '126.5311884',
    'p_sido_cd':'16', # 01=서울시, 08=경기 ... 16=제주
    'p_gugun_cd':'',  # 세부지역 (지정하지 않으면 시/도 전체)
    'in_biz_cd':'',
    'set_date':'',
    'iend':'1000',
}
    
url = 'https://www.starbucks.co.kr/store/getStore.do'
r = requests.post(url, data=data)
df = json_normalize(json.loads(r.text), 'list')

map_osm = folium.Map(location=(33.361666, 126.529166), zoom_start=10)
for ix, row in df.iterrows():
    location = (row['lat'], row['lot'])
    folium.Marker(location, popup=row['s_name']).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b4b5be097b76e634fe9b32742af986b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b4b5be097b76e634fe9b32742af986b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b4b5be097b76e634fe9b32742af986b = L.map(
#                 &quot;map_5b4b5be097b76e634fe9b32742af986b&quot;,
#                 {
#                     center: [33.361666, 126.529166],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6858f15e23924beac320031374c3c53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f6858f15e23924beac320031374c3c53.addTo(map_5b4b5be097b76e634fe9b32742af986b);
#
#
#             var marker_c38cb7aaebbb0418fd4377db8358a126 = L.marker(
#                 [33.3057863, 126.3163825],
#                 {}
#             ).addTo(map_5b4b5be097b76e634fe9b32742af986b);
#
#
#         var popup_a01d5f8a323c3a5a5c4e087b8962b866 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31cd3b02cb7b9ed0c5d934914eccc9f9 = $(`&lt;div id=&quot;html_31cd3b02cb7b9ed0c5d934914eccc9f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주신화월드R&lt;/div&gt;`)[0];
#                 popup_a01d5f8a323c3a5a5c4e087b8962b866.setContent(html_31cd3b02cb7b9ed0c5d934914eccc9f9);
#
#
#
#         marker_c38cb7aaebbb0418fd4377db8358a126.bindPopup(popup_a01d5f8a323c3a5a5c4e087b8962b866)
#         ;
#
#
#
#
#             var marker_8d502248ea5bf9c8c6f814adea349f92 = L.marker(
#                 [33.291788, 126.284407],
#                 {}
#             ).addTo(map_5b4b5be097b76e634fe9b32742af986b);
#
#
#         var popup_86e0eacf0d57f0815f2776a39c0c1431 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_794806c5f26f9a7c1f208007c7655d57 = $(`&lt;div id=&quot;html_794806c5f26f9a7c1f208007c7655d57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주에듀시티&lt;/div&gt;`)[0];
#                 popup_86e0eacf0d57f0815f2776a39c0c1431.setContent(html_794806c5f26f9a7c1f208007c7655d57);
#
#
#
#         marker_8d502248ea5bf9c8c6f814adea349f92.bindPopup(popup_86e0eacf0d57f0815f2776a39c0c1431)
#         ;
#
#
#
#
#             var marker_e9a34f20c7363d4664150b0a39acafe3 = L.marker(
#                 [33.449718, 126.9207013],
#                 {}
#             ).addTo(map_5b4b5be097b76e634fe9b32742af986b);
#
#
#         var popup_a98e01cb71ca2173185da5b8badfd18a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b7deaea714337e111edc24c367e55d4c = $(`&lt;div id=&quot;html_b7deaea714337e111edc24c367e55d4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주성산DT&lt;/div&gt;`)[0];
#                 popup_a98e01cb71ca2173185da5b8badfd18a.setContent(html_b7deaea714337e111edc24c367e55d4c);
#
#
#
#         marker_e9a34f20c7363d4664150b0a39acafe3.bindPopup(popup_a98e01cb71ca2173185da5b8badfd18a)
#         ;
#
#
#
#
#             var marker_174918b32662c71a234f8eae6b1dbbcf = L.marker(
#                 [33.255226, 126.4159053],
#                 {}
#             ).addTo(map_5b4b5be097b76e634fe9b32742af986b);
#
#
#         var popup_b6365f9d9c81ffe092994561b9bf1581 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e6e40295fc9e58c370eebe984c071c6 = $(`&lt;div id=&quot;html_3e6e40295fc9e58c370eebe984c071c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주중문DT&lt;/div&gt;`)[0];
#                 popup_b6365f9d9c81ffe092994561b9bf1581.setContent(html_3e6e40295fc9e58c370eebe984c071c6);
#
#
#
#         marker_174918b32662c71a234f8eae6b1dbbcf.bindPopup(popup_b6365f9d9c81ffe092994561b9bf1581)
#         ;
#
#
#
#
#             var marker_0346d2dba7a77efdba14b23f0221585a = L.marker(
#                 [33.2067772259681, 126.289973082566],
#                 {}
#             ).addTo(map_5b4b5be097b76e634fe9b32742af986b);
#
#
#         var popup_d7179c043021a43d3ace7f7dcc3e45bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9f5dda93a75cb64bfc7d475f2a08d4db = $(`&lt;div id=&quot;html_9f5dda93a75cb64bfc7d475f2a08d4db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;제주송악산&lt;/div&gt;`)[0];
#                 popup_d7179c043021a43d3ace7f7dcc3e45bb.setContent(html_9f5dda93a75cb64bfc7d475f2a08d4db);
#
#
#
#         marker_0346d2dba7a77efdba14b23f0221585a.bindPopup(popup_d7179c043021a43d3ace7f7dcc3e45bb)
#         ;
#
#
#
#
#             var marker_1d13b42ea765117b22de13a796a54957 = L.marker(
#                 [33.2492775, 126.50652289999994],
#                 {}
#             ).addTo(map_5b4b5be097b76e634fe9b32742af986b);

# %%
df[['s_name', 'gugun_name', 'doro_address', 'tel']]
# Out:
#        s_name gugun_name                             doro_address        tel
# 0     제주신화월드R       서귀포시     제주특별자치도 서귀포시 안덕면 신화역사로304번길 38 B1-29  1522-3232
# 1      제주에듀시티       서귀포시               제주특별자치도 서귀포시 대정읍 에듀시티로 36   1522-3232
# 2      제주성산DT       서귀포시                 제주특별자치도 서귀포시 성산읍 일출로 80   1522-3232
# 3      제주중문DT       서귀포시                제주특별자치도 서귀포시 천제연로 95(색달동)  1522-3232
# 4       제주송악산       서귀포시               제주특별자치도 서귀포시 대정읍 형제해안로 322  1522-3232
# 5       서귀포DT       서귀포시               제주특별자치도 서귀포시 일주서로 11 (강정동)  1522-3232
# 6       성산일출봉       서귀포시          제주특별자치도 서귀포시 성산읍 일출로 284-5 1,2층  1522-3232
# 7        제주중문       서귀포시         제주특별자치도 서귀포시 중문관광로110번길 32 (색달동)  1522-3232
# 8       서귀포올레       서귀포시                제주특별자치도 서귀포시 중정로 69 (서귀동)  1522-3232
# 9   제주서귀포토평DT       서귀포시             제주특별자치도 서귀포시 일주동로 8516 (토평동)  1522-3232
# 10    제주모슬포DT       서귀포시              제주특별자치도 서귀포시 대정읍 일주서로 2549   1522-3232
# 11  제주서귀포남원DT       서귀포시              제주특별자치도 서귀포시 남원읍 일주동로 7129   1522-3232
# 12     제주도남DT        제주시                제주특별자치도 제주시 연북로 394 (도남동)  1522-3232
# 13       제주협재        제주시                 제주특별자치도 제주시 한림읍 한림로 337   1522-3232
# 14     제주외도DT        제주시             제주특별자치도 제주시 일주서로 7300 (외도일동)  1522-3232
# 15     제주삼화DT        제주시               제주특별자치도 제주시 연삼로 884 (도련일동)  1522-3232
# 16       제주시청        제주시               제주특별자치도 제주시 중앙로 215 (이도이동)  1522-3232
# 17     제주애월DT        제주시               제주특별자치도 제주시 애월읍 애월해안로 376   1522-3232
# 18       제주칠성        제주시                제주특별자치도 제주시 관덕로 55 (일도일동)  1522-3232
# 19       제주노형        제주시                 제주특별자치도 제주시 도령로 27 (노형동)  1522-3232
# 20     제주용담DT        제주시       제주특별자치도 제주시 서해안로 380 (용담삼동) 화이트하우스  1522-3232
# 21     신제주이마트        제주시  제주특별자치도 제주시 1100로 3348, 신제주이마트 1층 (노형동)  1522-3232
# 22     제주세화DT        제주시               제주특별자치도 제주시 구좌읍 일주동로 3121   1522-3232
# 23      제주노형로        제주시                제주특별자치도 제주시 노형로 376 (노형동)  1522-3232
# 24     제주노형DT        제주시                 제주특별자치도 제주시 월랑로 68 (노형동)  1522-3232
# 25  제주한라수목원DT        제주시              제주특별자치도 제주시 수목원서길 3-5 (노형동)  1522-3232
# 26   제주서해안로DT        제주시              제주특별자치도 제주시 서해안로 624 (용담삼동)  1522-3232
# 27     제주일도DT        제주시               제주특별자치도 제주시 동광로 130 (일도이동)  1522-3232
# 28     제주공항DT        제주시                제주특별자치도 제주시 월성로 42 (용담이동)  1522-3232
# 29     제주금악DT        제주시              제주특별자치도 제주시 한림읍 평화로 1360-2   1522-3232
# 30   제주한담해변DT        제주시               제주특별자치도 제주시 애월읍 일주서로 6142   1522-3232
# 31   더제주송당파크R        제주시               제주특별자치도 제주시 구좌읍 비자림로 1189   1522-3232
# 32    제주평화로DT        제주시                 제주특별자치도 제주시 노형로 37 (해안동)  1522-3232

# %%
from geopy.geocoders import Nominatim
nom = Nominatim(user_agent = 'South Korea', timeout=None)
n = nom.geocode("London Tower")
print(n.latitude, n.longitude)
print(n.address)
# Out:
# 62.9276526 -150.6445964
# London Tower, Matanuska-Susitna Borough, Alaska, United States

# %%
n = nom.geocode("고려대학교")
print(n.latitude, n.longitude)
print(n.address)
# Out:
# 37.5879631 127.0323459
# 고려대학교 서울캠퍼스, 145, 안암로, 제기동, 용신동, 동대문구, 서울특별시, 02841, 대한민국

# %%
map_3 = folium.Map(location=[n.latitude, n.longitude], tiles='openstreetmap', zoom_start=20)
folium.Marker([n.latitude, n.longitude], popup='The Waterfront').add_to(map_3)
folium.CircleMarker([n.latitude, n.longitude], radius=10,
                   popup='My Lab', color='red',
                   fill_color='#3186cc').add_to(map_3)
map_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cce59ec10de12ec772cdbeeafd060dec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cce59ec10de12ec772cdbeeafd060dec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cce59ec10de12ec772cdbeeafd060dec = L.map(
#                 &quot;map_cce59ec10de12ec772cdbeeafd060dec&quot;,
#                 {
#                     center: [37.5879631, 127.0323459],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f27f81236bd8566a3c4bda2c17a3c0c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f27f81236bd8566a3c4bda2c17a3c0c1.addTo(map_cce59ec10de12ec772cdbeeafd060dec);
#
#
#             var marker_7f2d41bd892091d27f64f892aa8160c1 = L.marker(
#                 [37.5879631, 127.0323459],
#                 {}
#             ).addTo(map_cce59ec10de12ec772cdbeeafd060dec);
#
#
#         var popup_0d3e9aae2bcfcfbe8e9c81930854daf8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dee72dacb0a38d401c4ac8ebe4c5141 = $(`&lt;div id=&quot;html_9dee72dacb0a38d401c4ac8ebe4c5141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_0d3e9aae2bcfcfbe8e9c81930854daf8.setContent(html_9dee72dacb0a38d401c4ac8ebe4c5141);
#
#
#
#         marker_7f2d41bd892091d27f64f892aa8160c1.bindPopup(popup_0d3e9aae2bcfcfbe8e9c81930854daf8)
#         ;
#
#
#
#
#             var circle_marker_c68a01a441ceb4ae8d95fbb3a7ad58d9 = L.circleMarker(
#                 [37.5879631, 127.0323459],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cce59ec10de12ec772cdbeeafd060dec);
#
#
#         var popup_4ac3515b2202912016720d4d150565ac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b5bda2d16bab1f4042c643e5db637d88 = $(`&lt;div id=&quot;html_b5bda2d16bab1f4042c643e5db637d88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Lab&lt;/div&gt;`)[0];
#                 popup_4ac3515b2202912016720d4d150565ac.setContent(html_b5bda2d16bab1f4042c643e5db637d88);
#
#
#
#         circle_marker_c68a01a441ceb4ae8d95fbb3a7ad58d9.bindPopup(popup_4ac3515b2202912016720d4d150565ac)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 요약
# * requests.post() 데이터 가져오기
# * json_normalize(): JSON 데이터 DataFrame으로 전환
# * folium 을 사용하여 지도에 위치 표시

# %% [markdown]
# ### 2018 FinanceData.KR [fb.com/financedata](fb.com/financedata)
